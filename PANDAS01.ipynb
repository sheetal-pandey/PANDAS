# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c','d']
l1=[10,20,30,40]
arr1=np.array([10,20,30,50])
dict1={'a':10,'b':20,'c':30,'d':35}

# %% [markdown]
# #**using list**

# %%
s1=pd.Series(data=l1)
print(s1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pd.Series(data=l1,index=labels)#INDEX ASSINGED CHARACTERS
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
pd.Series(l1,labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# #**numpy arrays to series**

# %%
pd.Series(arr1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    50
# dtype: int64

# %% [markdown]
# #**dictionaries to series**

# %%
pd.Series(dict1)
# Out:
# a    10
# b    20
# c    30
# d    35
# dtype: int64

# %%
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
pd.Series([sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %% [markdown]
# #**use of index in pandas series**

# %%
ser1=pd.Series(['WASHINGTON DC','BERLIN','MOSCOW','TOKYO'],index=['USA','GERMANY','RUSSIA','JAPAN'])

# %%
ser1
# Out:
# USA        WASHINGTON DC
# GERMANY           BERLIN
# RUSSIA            MOSCOW
# JAPAN              TOKYO
# dtype: object

# %%
ser2=pd.Series(['1154','5132','554','547'],index=['USA','GERMANY','RUSSIA','JAPAN'])

# %%
ser2
# Out:
# USA        1154
# GERMANY    5132
# RUSSIA      554
# JAPAN       547
# dtype: object

# %%
s=pd.Series([1,2,3,4],index=["a","b","c","d"])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s["a"]
# Out:
# np.int64(1)

# %%
s2=s.reindex(["b","d","a","c","e"])

# %%
s2
# Out:
# b    2.0
# d    4.0
# a    1.0
# c    3.0
# e    NaN
# dtype: float64

# %%
s3=pd.Series(["blue","red","yellow"])
print(s3)
# Out:
# 0      blue
# 1       red
# 2    yellow
# dtype: object

# %%
s3=pd.Series(["blue","red","yellow"],index=[0,2,4])
print(s3)
# Out:
# 0      blue
# 2       red
# 4    yellow
# dtype: object

# %%
s3.reindex(range(6),method="ffill")
# Out:
# 0      blue
# 1      blue
# 2       red
# 3       red
# 4    yellow
# 5    yellow
# dtype: object

# %% [markdown]
# #**ARITHMETIC OPERATION**

# %%
s1=pd.Series(np.arange(5),index=["a","b","c","d","i"])
print(s1)
# Out:
# a    0
# b    1
# c    2
# d    3
# i    4
# dtype: int64

# %%
s2=pd.Series(np.arange(4),index=["a","g","h","i"])
print(s2)
# Out:
# a    0
# g    1
# h    2
# i    3
# dtype: int64

# %%
s1+s2
# Out:
# a    0.0
# b    NaN
# c    NaN
# d    NaN
# g    NaN
# h    NaN
# i    7.0
# dtype: float64

# %% [markdown]
# #**DATA FRAMES IN PANDAS**

# %%
data={"name":["Aditya","Anshika","Arpit","Dolly","Husba","Pranjal","Pragya"],
      "score":[75,94,99,65,68,55,88],
      "sports":["skates","badminton","video games","table tennis","cricket","basketball","tennis"],
      "sex":["M","F","M","F","F","M","F"]}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#       name  score        sports sex
# 0   Aditya     75        skates   M
# 1  Anshika     94     badminton   F
# 2    Arpit     99   video games   M
# 3    Dolly     65  table tennis   F
# 4    Husba     68       cricket   F
# 5  Pranjal     55    basketball   M
# 6   Pragya     88        tennis   F

# %%
df=pd.DataFrame(data,columns=["name","sports","sex","score"])
print(df)
# Out:
#       name        sports sex  score
# 0   Aditya        skates   M     75
# 1  Anshika     badminton   F     94
# 2    Arpit   video games   M     99
# 3    Dolly  table tennis   F     65
# 4    Husba       cricket   F     68
# 5  Pranjal    basketball   M     55
# 6   Pragya        tennis   F     88

# %%
df.head()
# Out:
#       name        sports sex  score
# 0   Aditya        skates   M     75
# 1  Anshika     badminton   F     94
# 2    Arpit   video games   M     99
# 3    Dolly  table tennis   F     65
# 4    Husba       cricket   F     68

# %%
df.tail()
# Out:
#       name        sports sex  score
# 2    Arpit   video games   M     99
# 3    Dolly  table tennis   F     65
# 4    Husba       cricket   F     68
# 5  Pranjal    basketball   M     55
# 6   Pragya        tennis   F     88

# %%
df.tail(2)
# Out:
#       name      sports sex  score
# 5  Pranjal  basketball   M     55
# 6   Pragya      tennis   F     88

# %%
df.tail(3)
# Out:
#       name      sports sex  score
# 4    Husba     cricket   F     68
# 5  Pranjal  basketball   M     55
# 6   Pragya      tennis   F     88

# %%
df.head(3)
# Out:
#       name       sports sex  score
# 0   Aditya       skates   M     75
# 1  Anshika    badminton   F     94
# 2    Arpit  video games   M     99

# %%
df=pd.DataFrame(data,columns=["name","sports","sex","score"])
df
# Out:
#       name        sports sex  score
# 0   Aditya        skates   M     75
# 1  Anshika     badminton   F     94
# 2    Arpit   video games   M     99
# 3    Dolly  table tennis   F     65
# 4    Husba       cricket   F     68
# 5  Pranjal    basketball   M     55
# 6   Pragya        tennis   F     88

# %%
df=pd.DataFrame(data,columns=["name","sports","sex","score","age","address"],
             index=["one","two","three","four","five","six","seven",])
df
# Out:
#           name        sports sex  score  age address
# one     Aditya        skates   M     75  NaN     NaN
# two    Anshika     badminton   F     94  NaN     NaN
# three    Arpit   video games   M     99  NaN     NaN
# four     Dolly  table tennis   F     65  NaN     NaN
# five     Husba       cricket   F     68  NaN     NaN
# six    Pranjal    basketball   M     55  NaN     NaN
# seven   Pragya        tennis   F     88  NaN     NaN

# %%
df["score"]   #fetching column
# Out:
# one      75
# two      94
# three    99
# four     65
# five     68
# six      55
# seven    88
# Name: score, dtype: int64

# %%
df[["name","sports"]]  #fetching multiple columns
# Out:
#           name        sports
# one     Aditya        skates
# two    Anshika     badminton
# three    Arpit   video games
# four     Dolly  table tennis
# five     Husba       cricket
# six    Pranjal    basketball
# seven   Pragya        tennis

# %%
df2=df[["name","sports"]] #creating new data frame
df2
# Out:
#           name        sports
# one     Aditya        skates
# two    Anshika     badminton
# three    Arpit   video games
# four     Dolly  table tennis
# five     Husba       cricket
# six    Pranjal    basketball
# seven   Pragya        tennis

# %%
id(df2)
# Out:
# 136490556523584

# %%
id(df) #id of df2 is different from id of df
# Out:
# 136490683253248

# %%
df.score
# Out:
# one      75
# two      94
# three    99
# four     65
# five     68
# six      55
# seven    88
# Name: score, dtype: int64

# %%
df.loc[["one"]] #fetching row
# Out:
#        name  sports sex  score  age address
# one  Aditya  skates   M     75  NaN     NaN

# %%
df.loc[["one","four"]] #fetching different rows together
# Out:
#         name        sports sex  score  age address
# one   Aditya        skates   M     75  NaN     NaN
# four   Dolly  table tennis   F     65  NaN     NaN

# %%
df["age"]=20 #giving defaultvalue to age dataset
df
# Out:
#           name        sports sex  score  age address
# one     Aditya        skates   M     75   20     NaN
# two    Anshika     badminton   F     94   20     NaN
# three    Arpit   video games   M     99   20     NaN
# four     Dolly  table tennis   F     65   20     NaN
# five     Husba       cricket   F     68   20     NaN
# six    Pranjal    basketball   M     55   20     NaN
# seven   Pragya        tennis   F     88   20     NaN

# %%
add=["noida","bengaluru","jamshedpur","lucknow","lucknow","lakhimpur","delhi"]
df["address"]=add
df
# Out:
#           name        sports sex  score  age     address
# one     Aditya        skates   M     75   20       noida
# two    Anshika     badminton   F     94   20   bengaluru
# three    Arpit   video games   M     99   20  jamshedpur
# four     Dolly  table tennis   F     65   20     lucknow
# five     Husba       cricket   F     68   20     lucknow
# six    Pranjal    basketball   M     55   20   lakhimpur
# seven   Pragya        tennis   F     88   20       delhi

# %%
df3=pd.DataFrame(data,columns=["name","sports","sex","score","age","address"])
df3
# Out:
#       name        sports sex  score  age address
# 0   Aditya        skates   M     75  NaN     NaN
# 1  Anshika     badminton   F     94  NaN     NaN
# 2    Arpit   video games   M     99  NaN     NaN
# 3    Dolly  table tennis   F     65  NaN     NaN
# 4    Husba       cricket   F     68  NaN     NaN
# 5  Pranjal    basketball   M     55  NaN     NaN
# 6   Pragya        tennis   F     88  NaN     NaN

# %%
age_val=[22,21,21,20,20,22,21]
df3["age"]=age_val
df3
# Out:
#       name        sports sex  score  age address
# 0   Aditya        skates   M     75   22     NaN
# 1  Anshika     badminton   F     94   21     NaN
# 2    Arpit   video games   M     99   21     NaN
# 3    Dolly  table tennis   F     65   20     NaN
# 4    Husba       cricket   F     68   20     NaN
# 5  Pranjal    basketball   M     55   22     NaN
# 6   Pragya        tennis   F     88   21     NaN

# %%
add==["Noida","Bengaluru","Jamshedpur","Lucknow","Lucknow","Lakhimpur","Delhi"]
df3["address"]=add
df3
# Out:
#       name        sports sex  score  age     address
# 0   Aditya        skates   M     75   22       noida
# 1  Anshika     badminton   F     94   21   bengaluru
# 2    Arpit   video games   M     99   21  jamshedpur
# 3    Dolly  table tennis   F     65   20     lucknow
# 4    Husba       cricket   F     68   20     lucknow
# 5  Pranjal    basketball   M     55   22   lakhimpur
# 6   Pragya        tennis   F     88   21       delhi

# %%
df3["toppers"]=df3.score>75
df3
# Out:
#       name        sports sex  score  age     address  toppers
# 0   Aditya        skates   M     75   22       noida    False
# 1  Anshika     badminton   F     94   21   bengaluru     True
# 2    Arpit   video games   M     99   21  jamshedpur     True
# 3    Dolly  table tennis   F     65   20     lucknow    False
# 4    Husba       cricket   F     68   20     lucknow    False
# 5  Pranjal    basketball   M     55   22   lakhimpur    False
# 6   Pragya        tennis   F     88   21       delhi     True

# %%
scores={"AM604":{"A":80,"B":70,"C":60},"AM501":{"A":90,"B":80,"C":60}}

# %%
score_df=pd.DataFrame(scores)
score_df
# Out:
#    AM604  AM501
# A     80     90
# B     70     80
# C     60     60

# %%
score_df.T #TAKING TRANSPOSE
# Out:
#         A   B   C
# AM604  80  70  60
# AM501  90  80  60

# %%
df3.dtypes
# Out:
# name       object
# sports     object
# sex        object
# score       int64
# age         int64
# address    object
# toppers      bool
# dtype: object

# %%
df3.describe()
# Out:
#            score        age
# count   7.000000   7.000000
# mean   77.714286  21.000000
# std    16.347419   0.816497
# min    55.000000  20.000000
# 25%    66.500000  20.500000
# 50%    75.000000  21.000000
# 75%    91.000000  21.500000
# max    99.000000  22.000000

# %%
df3["score"].mean()
# Out:
# np.float64(77.71428571428571)

# %%
df3["score"].std()
# Out:
# 16.34741861084175

# %%
df3.sample(3)
# Out:
#       name        sports sex  score  age    address  toppers
# 3    Dolly  table tennis   F     65   20    lucknow    False
# 1  Anshika     badminton   F     94   21  bengaluru     True
# 4    Husba       cricket   F     68   20    lucknow    False

# %%
df3["score_age"]=df3['score']+df3['age']
df3
# Out:
#       name        sports sex  score  age     address  toppers  score_age
# 0   Aditya        skates   M     75   22       noida    False         97
# 1  Anshika     badminton   F     94   21   bengaluru     True        115
# 2    Arpit   video games   M     99   21  jamshedpur     True        120
# 3    Dolly  table tennis   F     65   20     lucknow    False         85
# 4    Husba       cricket   F     68   20     lucknow    False         88
# 5  Pranjal    basketball   M     55   22   lakhimpur    False         77
# 6   Pragya        tennis   F     88   21       delhi     True        109

# %%
df3.drop('score_age',axis=1)#deleting column
# Out:
#       name        sports sex  score  age     address  toppers
# 0   Aditya        skates   M     75   22       noida    False
# 1  Anshika     badminton   F     94   21   bengaluru     True
# 2    Arpit   video games   M     99   21  jamshedpur     True
# 3    Dolly  table tennis   F     65   20     lucknow    False
# 4    Husba       cricket   F     68   20     lucknow    False
# 5  Pranjal    basketball   M     55   22   lakhimpur    False
# 6   Pragya        tennis   F     88   21       delhi     True

# %%
df3
# Out:
#       name        sports sex  score  age     address  toppers  score_age
# 0   Aditya        skates   M     75   22       noida    False         97
# 1  Anshika     badminton   F     94   21   bengaluru     True        115
# 2    Arpit   video games   M     99   21  jamshedpur     True        120
# 3    Dolly  table tennis   F     65   20     lucknow    False         85
# 4    Husba       cricket   F     68   20     lucknow    False         88
# 5  Pranjal    basketball   M     55   22   lakhimpur    False         77
# 6   Pragya        tennis   F     88   21       delhi     True        109

# %%
df3.drop('score_age',axis=1,inplace=True) #deleting permanently column

# %%
df3
# Out:
#       name        sports sex  score  age     address  toppers
# 0   Aditya        skates   M     75   22       noida    False
# 1  Anshika     badminton   F     94   21   bengaluru     True
# 2    Arpit   video games   M     99   21  jamshedpur     True
# 3    Dolly  table tennis   F     65   20     lucknow    False
# 4    Husba       cricket   F     68   20     lucknow    False
# 5  Pranjal    basketball   M     55   22   lakhimpur    False
# 6   Pragya        tennis   F     88   21       delhi     True

# %%
df3.drop(4,axis=0)
# Out:
#       name        sports sex  score  age     address  toppers
# 0   Aditya        skates   M     75   22       noida    False
# 1  Anshika     badminton   F     94   21   bengaluru     True
# 2    Arpit   video games   M     99   21  jamshedpur     True
# 3    Dolly  table tennis   F     65   20     lucknow    False
# 5  Pranjal    basketball   M     55   22   lakhimpur    False
# 6   Pragya        tennis   F     88   21       delhi     True

# %%
df3.loc[2] #selecting row
# Out:
# name             Arpit
# sports     video games
# sex                  M
# score               99
# age                 21
# address     jamshedpur
# toppers           True
# Name: 2, dtype: object

# %%
df.loc['two']
# Out:
# name         Anshika
# sports     badminton
# sex                F
# score             94
# age               20
# address    bengaluru
# Name: two, dtype: object

# %%
df.iloc[1]
# Out:
# name         Anshika
# sports     badminton
# sex                F
# score             94
# age               20
# address    bengaluru
# Name: two, dtype: object

# %%
df.loc[['one','two']]
# Out:
#         name     sports sex  score  age    address
# one   Aditya     skates   M     75   20      noida
# two  Anshika  badminton   F     94   20  bengaluru

# %%
df.loc[['one','two'],['name','sports','score','age']]
# Out:
#         name     sports  score  age
# one   Aditya     skates     75   20
# two  Anshika  badminton     94   20

# %%
df['age']>50
# Out:
# one      False
# two      False
# three    False
# four     False
# five     False
# six      False
# seven    False
# Name: age, dtype: bool

# %%
df[df['score']>70]
# Out:
#           name       sports sex  score  age     address
# one     Aditya       skates   M     75   20       noida
# two    Anshika    badminton   F     94   20   bengaluru
# three    Arpit  video games   M     99   20  jamshedpur
# seven   Pragya       tennis   F     88   20       delhi

# %%
df[df['score']>70]['name']
# Out:
# one       Aditya
# two      Anshika
# three      Arpit
# seven     Pragya
# Name: name, dtype: object

# %%
df[(df['score']>70) & (df['score']<80)]
# Out:
#        name  sports sex  score  age address
# one  Aditya  skates   M     75   20   noida

# %%
df[(df['score']>70) | (df['score']<80)]
# Out:
#           name        sports sex  score  age     address
# one     Aditya        skates   M     75   20       noida
# two    Anshika     badminton   F     94   20   bengaluru
# three    Arpit   video games   M     99   20  jamshedpur
# four     Dolly  table tennis   F     65   20     lucknow
# five     Husba       cricket   F     68   20     lucknow
# six    Pranjal    basketball   M     55   20   lakhimpur
# seven   Pragya        tennis   F     88   20       delhi

# %%
df3.reset_index()
# Out:
#    index     name        sports sex  score  age     address  toppers
# 0      0   Aditya        skates   M     75   22       noida    False
# 1      1  Anshika     badminton   F     94   21   bengaluru     True
# 2      2    Arpit   video games   M     99   21  jamshedpur     True
# 3      3    Dolly  table tennis   F     65   20     lucknow    False
# 4      4    Husba       cricket   F     68   20     lucknow    False
# 5      5  Pranjal    basketball   M     55   22   lakhimpur    False
# 6      6   Pragya        tennis   F     88   21       delhi     True

# %%
df3
# Out:
#       name        sports sex  score  age     address  toppers
# 0   Aditya        skates   M     75   22       noida    False
# 1  Anshika     badminton   F     94   21   bengaluru     True
# 2    Arpit   video games   M     99   21  jamshedpur     True
# 3    Dolly  table tennis   F     65   20     lucknow    False
# 4    Husba       cricket   F     68   20     lucknow    False
# 5  Pranjal    basketball   M     55   22   lakhimpur    False
# 6   Pragya        tennis   F     88   21       delhi     True
