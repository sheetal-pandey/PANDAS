# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("/content/car-sales.csv")

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data.loc[[1,2]]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
data[["Make","Odometer (KM)","Doors"]]
# Out:
#      Make  Odometer (KM)  Doors
# 0  Toyota         150043      4
# 1   Honda          87899      4
# 2  Toyota          32549      3
# 3     BMW          11179      5
# 4  Nissan         213095      4
# 5  Toyota          99213      4
# 6   Honda          45698      4
# 7   Honda          54738      4
# 8  Toyota          60000      4
# 9  Nissan          31600      4

# %%
import matplotlib.pyplot as plt

# %%
data["Price"]=data["Price"].str.replace(r"[\$\,\.]","",regex=True)

# %%
data["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
data["Price"]=data["Price"].astype(int)
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
data["Price"].plot()
# Out:
# <Axes: >

# %%
data["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
data_missing=pd.read_csv("/content/car-sales-missing-data.csv")
data_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
data_missing["Odometer"].fillna(data_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
data_missing.dropna(inplace=True)
data_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
data_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
engine_sizes=[1.3,4.3,2.3,3.3,4.3,3.0,2.3,4.5,3.5,2.9]
data["Engine Size"]=engine_sizes
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size
# 0  Toyota  White         150043      4   400000          1.3
# 1   Honda    Red          87899      4   500000          4.3
# 2  Toyota   Blue          32549      3   700000          2.3
# 3     BMW  Black          11179      5  2200000          3.3
# 4  Nissan  White         213095      4   350000          4.3
# 5  Toyota  Green          99213      4   450000          3.0
# 6   Honda   Blue          45698      4   750000          2.3
# 7   Honda   Blue          54738      4   700000          4.5
# 8  Toyota  White          60000      4   625000          3.5
# 9  Nissan  White          31600      4   970000          2.9

# %%
data["Price per KM"]=data["Price"]/data["Odometer (KM)"]
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size  Price per KM
# 0  Toyota  White         150043      4   400000          1.3      2.665902
# 1   Honda    Red          87899      4   500000          4.3      5.688347
# 2  Toyota   Blue          32549      3   700000          2.3     21.506037
# 3     BMW  Black          11179      5  2200000          3.3    196.797567
# 4  Nissan  White         213095      4   350000          4.3      1.642460
# 5  Toyota  Green          99213      4   450000          3.0      4.535696
# 6   Honda   Blue          45698      4   750000          2.3     16.412097
# 7   Honda   Blue          54738      4   700000          4.5     12.788191
# 8  Toyota  White          60000      4   625000          3.5     10.416667
# 9  Nissan  White          31600      4   970000          2.9     30.696203

# %%
data=data.drop("Price per KM",axis=1)
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size
# 0  Toyota  White         150043      4   400000          1.3
# 1   Honda    Red          87899      4   500000          4.3
# 2  Toyota   Blue          32549      3   700000          2.3
# 3     BMW  Black          11179      5  2200000          3.3
# 4  Nissan  White         213095      4   350000          4.3
# 5  Toyota  Green          99213      4   450000          3.0
# 6   Honda   Blue          45698      4   750000          2.3
# 7   Honda   Blue          54738      4   700000          4.5
# 8  Toyota  White          60000      4   625000          3.5
# 9  Nissan  White          31600      4   970000          2.9

# %%
data_sampled = data_sampled=data.sample(frac=1)
data_sampled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size
# 0  Toyota  White         150043      4   400000          1.3
# 7   Honda   Blue          54738      4   700000          4.5
# 1   Honda    Red          87899      4   500000          4.3
# 2  Toyota   Blue          32549      3   700000          2.3
# 6   Honda   Blue          45698      4   750000          2.3
# 4  Nissan  White         213095      4   350000          4.3
# 8  Toyota  White          60000      4   625000          3.5
# 9  Nissan  White          31600      4   970000          2.9
# 3     BMW  Black          11179      5  2200000          3.3
# 5  Toyota  Green          99213      4   450000          3.0

# %%
data= data.rename(columns={"Odometer (KM)":"Odometer (Miles)"})
data
# Out:
#      Make Colour  Odometer (Miles)  Doors    Price  Engine Size
# 0  Toyota  White            150043      4   400000          1.3
# 1   Honda    Red             87899      4   500000          4.3
# 2  Toyota   Blue             32549      3   700000          2.3
# 3     BMW  Black             11179      5  2200000          3.3
# 4  Nissan  White            213095      4   350000          4.3
# 5  Toyota  Green             99213      4   450000          3.0
# 6   Honda   Blue             45698      4   750000          2.3
# 7   Honda   Blue             54738      4   700000          4.5
# 8  Toyota  White             60000      4   625000          3.5
# 9  Nissan  White             31600      4   970000          2.9

# %%
import pandas as pd
df=pd.read_csv("/content/Pressure.txt")
df
# Out:
#       Timestamp\tPressure 0\tPressure 1\tPressure 2\tPressure 3\tPressure 4\tPressure 5\tPressure 6\tPressure 7\tSampling Rate
# 0      16:15:12\t14.522292\t-2176.031202\t-2174.59738...
# 1      16:15:12\t18.447389\t-2175.674327\t-2175.66813...
# 2      16:15:12\t12.381330\t-2175.317451\t-2174.95430...
# 3      16:15:12\t5.958444\t-2174.960576\t-2174.597387...
# 4      16:15:12\t7.385752\t-2175.317451\t-2174.954303...
# ...                                                  ...
# 39023  16:15:51\t16.306427\t-2175.674327\t-2174.59738...
# 39024  16:15:51\t2.033347\t-2175.317451\t-2174.954303...
# 39025  16:15:51\t17.733735\t-2174.960576\t-2175.31121...
# 39026  16:15:51\t19.161043\t-2175.317451\t-2175.31121...
# 39027  16:15:51\t6.672098\t-2175.317451\t-2175.311218...
#
# [39028 rows x 1 columns]
